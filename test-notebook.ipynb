# %%
import subprocess
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

import measure_time
# %reload_ext autoreload
# %autoreload 2

# %%
username = "stefan"
start_date = datetime(2023, 3, 16)
end_date = datetime.today() + timedelta(days=1)
get_user_usage = measure_time.get_user_usage("stefan", start_date, end_date)
measure_time.plot_user_usage(get_user_usage)
